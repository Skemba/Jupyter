# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
# If you provide single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values for it.
# Python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data is [0,1,2,3]
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
# Here we supply both x and y vectors
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
# For each (x,y) pair of arguments, we can add third argument which is the format string that indicates the color and line type of the plot
# You can concatenate a color string with a line style string. Default is 'b-' which is a solid blue line.
# Red circles would be:

plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# axis() command in the above code specifies the min and max x and y viewport of the axes

# Usually matplotlib is used with numpy thus we'll import it
import numpy as np

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# %%
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

# %%
# figure() command is optional because figure(1) will be created by default, just as subplot(111) will be created by default
# subplot() command specifies numrows, numcols, fignum where fignum ranges from 1 to numrows*numcols
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()
